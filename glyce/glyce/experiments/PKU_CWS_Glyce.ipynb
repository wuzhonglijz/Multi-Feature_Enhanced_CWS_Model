# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !pip install pypinyin pywubi zhconv overrides boto3
# Out:
# ...
#      |████████████████████████████████| 1.3 MB 12.6 MB/s
# ...
#      |████████████████████████████████| 132 kB 58.7 MB/s
# ...
#      |████████████████████████████████| 183 kB 53.6 MB/s
# ...
#      |████████████████████████████████| 131 kB 55.2 MB/s
# ...
#      |████████████████████████████████| 7.7 MB 46.3 MB/s
# ...
#      |████████████████████████████████| 79 kB 7.7 MB/s
# ...
#      |████████████████████████████████| 138 kB 62.8 MB/s
# ...
#   Created wheel for zhconv: filename=zhconv-1.4.2-py2.py3-none-any.whl size=181082 sha256=0af4f083fd4297ab9de74e3b1af803d65f4be762b6a5c8f81bb98a7bc749b2d8
#   Stored in directory: /root/.cache/pip/wheels/10/31/84/fca23def9be1db201eeaa76f4ee50a7d64f6e20ee7b223cc4f
# Successfully built zhconv
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ...

# %%
import time
import torch
print(torch.cuda.get_device_name(0))
start = time.perf_counter()
# Out:
# Tesla P100-PCIE-16GB

# %%
# !python3 "../bin/run_bert_glyce_tagger.py" \
--data_sign pku_cws \
--task_name cws \
--config_path "../configs/ctb6cws_glyce_bert.json" \
--data_dir "/home/wzl/msc/StrokeOrderEmbeddings/data/cws/pku" \
--output_name "/home/wzl/msc/StrokeOrderEmbeddings/my_export_models/pku_cws glyce.bin" \
--bert_model "/home/wzl/msc/StrokeOrderEmbeddings/data/chinese_L-12_H-768_A-12" \
--checkpoint 715 \
--seed 8008 \
--max_seq_length 90 \
--do_train \
--do_eval \
--train_batch_size 24 \
--dev_batch_size 24 \
--test_batch_size 24 \
--learning_rate 3e-5 \
--num_train_epochs 5 \
--warmup_proportion 0 \
--training_strat "bert-glyce-joint"
# Out:
# Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex.
# PATH to render.py
# =*=*=*=*=*=*=*=*=*=*
# /home/wzl/msc/StrokeOrderEmbeddings/glyce
# PRINT default FONT PATH
# ********************
# /home/wzl/msc/StrokeOrderEmbeddings/glyce/glyce/fonts
# ********************
# Please Notice that Merge the args_dict and json_config ... ...
# {
#   "glyph_ratio": 1e-06,
#   "glyph_decay": 0.85,
#   "glyph_warmup": 0,
#   "bert_frozen": "true",
#   "hidden_size": 1536,
#   "hidden_dropout_prob": 0,
#   "clip_grad": 1,
#   "bert_config": {
#     "attention_probs_dropout_prob": 0.1,
#     "directionality": "bidi",
#     "hidden_act": "gelu",
#     "hidden_dropout_prob": 0.1,
#     "hidden_size": 768,
#     "initializer_range": 0.02,
#     "intermediate_size": 3072,
#     "max_position_embeddings": 512,
#     "num_attention_heads": 12,
#     "num_hidden_layers": 12,
#     "pooler_fc_size": 768,
#     "pooler_num_attention_heads": 12,
# ...

# %%
end = time.perf_counter()
elapsed = end-start
hours = elapsed//(60*60)
mins = (elapsed - hours*60*60)//60
secs = (elapsed - hours*60*60 - mins*60)
print("Time elapsed: %02d:%02d:%02d" % (hours,mins,secs))
# Out:
# Time elapsed: 02:37:02
