# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !pip install pypinyin pywubi zhconv overrides boto3 ipywidgets
# Out:
# ...
#      |████████████████████████████████| 1.3 MB 9.0 MB/s
# ...
#      |████████████████████████████████| 132 kB 80.0 MB/s
# ...
#      |████████████████████████████████| 183 kB 78.6 MB/s
# ...
#      |████████████████████████████████| 131 kB 84.6 MB/s
# ...
#      |████████████████████████████████| 7.9 MB 56.0 MB/s
# ...
#      |████████████████████████████████| 79 kB 9.0 MB/s
# ...
#      |████████████████████████████████| 138 kB 95.6 MB/s
# ...
#   Created wheel for zhconv: filename=zhconv-1.4.2-py2.py3-none-any.whl size=181081 sha256=48288ed791e659c8abceaf8853d287604bc6ae623bc5fb2efb1496f6e74f6f07
#   Stored in directory: /root/.cache/pip/wheels/10/31/84/fca23def9be1db201eeaa76f4ee50a7d64f6e20ee7b223cc4f
# Successfully built zhconv
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ...

# %%
import time
import torch
print(torch.cuda.get_device_name(0))
start = time.perf_counter()
# Out:
# Tesla P100-PCIE-16GB

# %%
# !python3 "/content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/bin/run_bert_glyce_classifier.py" \
--data_sign fudan \
--task_name clf \
--data_dir "/content/gdrive/MyDrive/Colab Data/Chinese Characters/sent_cls/fudan" \
--output_name "/content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/my_export_models/fudan glyce.bin" \
--config_path "/content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/configs/glyce_bert.json" \
--bert_model "/content/gdrive/MyDrive/Colab Data/Chinese Characters/chinese_L-12_H-768_A-12" \
--seed 8008 \
--checkpoint 153 \
--max_seq_length 128 \
--do_train \
--do_eval \
--train_batch_size 24 \
--dev_batch_size 24 \
--test_batch_size 24 \
--learning_rate 3e-5 \
--num_train_epochs 15 \
--warmup_proportion 0 \
--training_strat "bert-glyce-joint"
# Out:
# check the root_path of this repo
# /content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce
# /content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce
# PATH to render.py
# =*=*=*=*=*=*=*=*=*=*
# /content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce
# PRINT default FONT PATH
# ********************
# /content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/fonts
# ********************
# /usr/local/lib/python3.7/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.6) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex.
# Please Notice that Merge the args_dict and json_config ... ...
# Update the config from args input
# {
#   "glyph_ratio": 0.1,
#   "glyph_decay": 0.1,
#   "glyph_warmup": 0,
#   "bert_frozen": "true",
#   "hidden_size": 1536,
#   "hidden_dropout_prob": 0.0,
#   "classifier_sign": "single_linear",
# ...

# %%
end = time.perf_counter()
elapsed = end-start
hours = elapsed//(60*60)
mins = (elapsed - hours*60*60)//60
secs = (elapsed - hours*60*60 - mins*60)
print("Time elapsed: %02d:%02d:%02d" % (hours,mins,secs))
# Out:
# Time elapsed: 00:34:58
