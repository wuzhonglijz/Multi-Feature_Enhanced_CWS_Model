# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !pip install pypinyin pywubi zhconv overrides boto3
# Out:
# Collecting pypinyin
#   Downloading pypinyin-0.42.0-py2.py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 9.6 MB/s
# Collecting pywubi
#   Downloading pywubi-0.0.2-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 51.4 MB/s
# Collecting zhconv
#   Downloading zhconv-1.4.2.tar.gz (183 kB)
#      |████████████████████████████████| 183 kB 46.5 MB/s
# Collecting overrides
#   Downloading overrides-6.1.0-py3-none-any.whl (14 kB)
# Collecting boto3
#   Downloading boto3-1.18.2-py3-none-any.whl (131 kB)
#      |████████████████████████████████| 131 kB 47.0 MB/s
# Collecting typing-utils>=0.0.3
#   Downloading typing_utils-0.1.0-py3-none-any.whl (10 kB)
# Collecting s3transfer<0.6.0,>=0.5.0
#   Downloading s3transfer-0.5.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 7.0 MB/s
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting botocore<1.22.0,>=1.21.2
#   Downloading botocore-1.21.2-py3-none-any.whl (7.7 MB)
#      |████████████████████████████████| 7.7 MB 33.5 MB/s
# Collecting urllib3<1.27,>=1.25.4
#   Downloading urllib3-1.26.6-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 57.5 MB/s
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.22.0,>=1.21.2->boto3) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.22.0,>=1.21.2->boto3) (1.15.0)
# Building wheels for collected packages: zhconv
#   Building wheel for zhconv (setup.py) ... done
#   Created wheel for zhconv: filename=zhconv-1.4.2-py2.py3-none-any.whl size=181082 sha256=06e6b05d6aafed83b4ace9c33a14ce8d67ae1f2048aaefae9b6cd8a0eb05beda
#   Stored in directory: /root/.cache/pip/wheels/10/31/84/fca23def9be1db201eeaa76f4ee50a7d64f6e20ee7b223cc4f
# Successfully built zhconv
# Installing collected packages: urllib3, jmespath, botocore, typing-utils, s3transfer, zhconv, pywubi, pypinyin, overrides, boto3
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.6 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed boto3-1.18.2 botocore-1.21.2 jmespath-0.10.0 overrides-6.1.0 pypinyin-0.42.0 pywubi-0.0.2 s3transfer-0.5.0 typing-utils-0.1.0 urllib3-1.26.6 zhconv-1.4.2

# %%
import time
import torch
print(torch.cuda.get_device_name(0))
start = time.perf_counter()
# Out:
# Tesla P100-PCIE-16GB

# %%
# !python3 "/content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/bin/run_bert_glyce_tagger.py" \
--data_sign ctb5_pos \
--task_name pos \
--config_path "/content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/configs/ctb6cws_glyce_bert.json" \
--data_dir "/content/gdrive/MyDrive/Colab Data/Chinese Characters/pos/ctb5" \
--output_name "/content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/my_export_models/ctb5_pos glyce.bin" \
--bert_model "/content/gdrive/MyDrive/Colab Data/Chinese Characters/chinese_L-12_H-768_A-12" \
--checkpoint 1724 \
--seed 8008 \
--max_seq_length 150 \
--do_train \
--do_eval \
--train_batch_size 16 \
--dev_batch_size 16 \
--test_batch_size 16 \
--learning_rate 3e-5 \
--num_train_epochs 15 \
--warmup_proportion 0 \
--training_strat "bert-glyce-joint"
# Out:
# /content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce
# PATH to render.py
# =*=*=*=*=*=*=*=*=*=*
# /content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce
# PRINT default FONT PATH
# ********************
# /content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/fonts
# ********************
# /usr/local/lib/python3.7/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.6) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex.
# Please Notice that Merge the args_dict and json_config ... ...
# {
#   "glyph_ratio": 1e-06,
#   "glyph_decay": 0.85,
#   "glyph_warmup": 0,
#   "bert_frozen": "true",
#   "hidden_size": 1536,
#   "hidden_dropout_prob": 0,
#   "clip_grad": 1,
#   "bert_config": {
#     "attention_probs_dropout_prob": 0.1,
#     "directionality": "bidi",
#     "hidden_act": "gelu",
#     "hidden_dropout_prob": 0.1,
#     "hidden_size": 768,
#     "initializer_range": 0.02,
#     "intermediate_size": 3072,
#     "max_position_embeddings": 512,
#     "num_attention_heads": 12,
#     "num_hidden_layers": 12,
#     "pooler_fc_size": 768,
#     "pooler_num_attention_heads": 12,
#     "pooler_num_fc_layers": 3,
#     "pooler_size_per_head": 128,
#     "pooler_type": "first_token_transform",
#     "type_vocab_size": 2,
#     "vocab_size": 21128
#   },
#   "glyph_config": {
#     "hidden_dropout_prob": 0.5,
#     "max_position_embeddings": 512,
#     "bert_model": "/content/gdrive/MyDrive/Colab Data/Chinese Characters/chinese_L-12_H-768_A-12",
#     "char2word_dim": 0,
#     "char_drop": 0.3,
#     "char_embsize": 0,
#     "cnn_dropout": 0.5,
#     "dropout": 0.5,
#     "fc_merge": false,
#     "font_channels": 1,
#     "font_name": "cjk/NotoSansCJKsc-Regular.otf",
#     "font_normalize": false,
#     "font_size": 18,
#     "glyph_cnn_type": "Yuxian8",
#     "glyph_embsize": 384,
#     "glyph_groups": 8,
#     "idx2char": null,
#     "idx2word": null,
#     "level": "char",
#     "loss_mask_ids": [
#       0,
#       102,
#       101
#     ],
#     "num_fonts_concat": 2,
#     "output_size": 768,
#     "pretrained_char_embedding": "",
#     "pretrained_word_embedding": "",
#     "random_erase": false,
#     "random_fonts": 0,
#     "subchar_embsize": 512,
#     "subchar_type": "",
#     "use_batch_norm": true,
#     "use_highway": false,
#     "use_layer_norm": false,
#     "use_maxpool": true,
#     "use_traditional": false,
#     "word_embsize": 1024,
#     "yuxian_merge": false,
#     "font_names": []
#   },
#   "transformer_config": {
#     "max_position_embeddings": 512,
#     "attention_probs_dropout_prob": 0.1,
#     "directionality": "bidi",
#     "hidden_act": "gelu",
#     "hidden_dropout_prob": 0.5,
#     "hidden_size": 1536,
#     "initializer_range": 0.02,
#     "intermediate_size": 6144,
#     "num_attention_heads": 24,
#     "num_hidden_layers": 1,
#     "pooler_fc_size": 1536,
#     "pooler_num_attention_heads": 12,
#     "pooler_num_fc_layers": 12,
#     "pooler_size_per_head": 256,
#     "pooler_type": "first_token_transform",
#     "type_vocab_size": 2,
#     "vocab_size": 21128
#   },
#   "config_path": "/content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/configs/ctb6cws_glyce_bert.json",
#   "data_dir": "/content/gdrive/MyDrive/Colab Data/Chinese Characters/pos/ctb5",
#   "bert_model": "/content/gdrive/MyDrive/Colab Data/Chinese Characters/chinese_L-12_H-768_A-12",
#   "task_name": "pos",
#   "cuda": true,
#   "max_seq_length": 150,
#   "do_train": true,
#   "do_eval": true,
#   "train_batch_size": 16,
#   "dev_batch_size": 16,
#   "checkpoint": 1724,
#   "test_batch_size": 16,
#   "learning_rate": 3e-05,
#   "num_train_epochs": 15.0,
#   "warmup_proportion": 0.0,
#   "local_rank": -1,
#   "gradient_accumulation_steps": 1,
#   "seed": 8008,
#   "export_model": true,
#   "output_name": "/content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/my_export_models/ctb5_pos glyce/training_1.bin",
#   "data_sign": "ctb5_pos",
#   "classifier_sign": "multi_nonlinear",
#   "residual": "no",
#   "training_strat": "bert-glyce-joint"
# }
# 27595it [00:13, 2118.97it/s]
# 352it [00:00, 2888.67it/s]
# 348it [00:00, 2651.83it/s]
# !=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!
# Please notice that the bert model if frozen
# the loaded weights of models is
# /content/gdrive/MyDrive/Colab Data/Chinese Characters/chinese_L-12_H-768_A-12
# !-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!
#
# Training Bert...
# ######################################################################
# EPOCH:  0
# 0it [00:00, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   warnings.warn(warning.format(ret))
# /content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/utils/optimization.py:142: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:1025.)
#   next_m.mul_(beta1).add_(1 - beta1, grad)
# 1723it [17:55,  1.60it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# taggging loss, glyph loss
# 0.05627300217747688 29.229110717773438
# 100% 22/22 [00:11<00:00,  1.99it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.0251 0.9666 0.9656 0.9661 0.9742
# 100% 22/22 [00:10<00:00,  2.02it/s]
# ............................................................
# TEST: loss, precision, recall, f1, acc
# 0.0382 0.961 0.9619 0.9615 0.97
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 1725it [18:21,  1.57it/s]
# ######################################################################
# EPOCH:  1
# 1723it [17:48,  1.60it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# taggging loss, glyph loss
# 0.050447702407836914 20.96905517578125
# 100% 22/22 [00:11<00:00,  1.99it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.0313 0.9698 0.9568 0.9633 0.9671
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 1725it [18:00,  1.60it/s]
# ######################################################################
# EPOCH:  2
# 1723it [17:45,  1.61it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# taggging loss, glyph loss
# 0.022158389911055565 20.741910934448242
# 100% 22/22 [00:11<00:00,  1.99it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.0262 0.9699 0.9686 0.9692 0.9761
# 100% 22/22 [00:10<00:00,  2.02it/s]
# ............................................................
# TEST: loss, precision, recall, f1, acc
# 0.0419 0.9541 0.9558 0.955 0.9661
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 1725it [18:09,  1.58it/s]
# ######################################################################
# EPOCH:  3
# 1723it [17:47,  1.61it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# taggging loss, glyph loss
# 0.0018403411377221346 20.805309295654297
# 100% 22/22 [00:11<00:00,  1.99it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.0301 0.9697 0.9727 0.9712 0.9762
# 100% 22/22 [00:10<00:00,  2.02it/s]
# ............................................................
# TEST: loss, precision, recall, f1, acc
# 0.0458 0.9594 0.9624 0.9609 0.9698
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 1725it [18:10,  1.58it/s]
# ######################################################################
# EPOCH:  4
# 1723it [17:46,  1.61it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# taggging loss, glyph loss
# 0.0025958088226616383 20.539749145507812
# 100% 22/22 [00:11<00:00,  1.99it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.036 0.9686 0.9686 0.9686 0.974
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 1725it [17:58,  1.60it/s]
#
# Training Glyce...
# ######################################################################
# EPOCH:  5
# 1723it [14:12,  2.03it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# taggging loss, glyph loss
# 0.004441270604729652 22.88458251953125
# 100% 22/22 [00:11<00:00,  1.99it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.0385 0.9687 0.969 0.9689 0.9752
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 1725it [14:24,  2.00it/s]
# ######################################################################
# EPOCH:  6
# 1723it [14:11,  2.03it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# taggging loss, glyph loss
# 0.0040580956265330315 22.733318328857422
# 100% 22/22 [00:11<00:00,  1.99it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.041 0.9676 0.9693 0.9685 0.9742
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 1725it [14:23,  2.00it/s]
# ######################################################################
# EPOCH:  7
# 1723it [14:10,  2.04it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# taggging loss, glyph loss
# 0.00046922272304072976 22.816299438476562
# 100% 22/22 [00:11<00:00,  1.99it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.0418 0.9688 0.9703 0.9696 0.9754
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 1725it [14:22,  2.00it/s]
# ######################################################################
# EPOCH:  8
# 1723it [14:11,  2.02it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# taggging loss, glyph loss
# 0.00012521215830929577 22.460716247558594
# 100% 22/22 [00:11<00:00,  2.00it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.0445 0.968 0.9693 0.9687 0.9737
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 1725it [14:23,  2.00it/s]
# ######################################################################
# EPOCH:  9
# 1723it [14:11,  2.03it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# taggging loss, glyph loss
# 0.0007593986811116338 22.776859283447266
# 100% 22/22 [00:11<00:00,  2.00it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.0469 0.9679 0.9696 0.9688 0.9749
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 1725it [14:23,  2.00it/s]
#
# Training Both...
# ######################################################################
# EPOCH:  10
# 1723it [19:35,  1.47it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# taggging loss, glyph loss
# 0.00030711747240275145 20.808347702026367
# 100% 22/22 [00:11<00:00,  2.00it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.05 0.9686 0.9693 0.969 0.9748
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 1725it [19:47,  1.45it/s]
# ######################################################################
# EPOCH:  11
# 1723it [19:34,  1.47it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# taggging loss, glyph loss
# 0.000309115246636793 21.259410858154297
# 100% 22/22 [00:11<00:00,  2.00it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.049 0.9687 0.9686 0.9687 0.974
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 1725it [19:47,  1.45it/s]
# ######################################################################
# EPOCH:  12
# 1723it [19:36,  1.47it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# taggging loss, glyph loss
# 0.0001043674856191501 21.434005737304688
# 100% 22/22 [00:11<00:00,  1.99it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.0512 0.9702 0.97 0.9701 0.9747
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 1725it [19:48,  1.45it/s]
# ######################################################################
# EPOCH:  13
# 1723it [19:33,  1.47it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# taggging loss, glyph loss
# 0.00045840427628718317 21.78252410888672
# 100% 22/22 [00:11<00:00,  2.00it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.0534 0.9693 0.9699 0.9696 0.9755
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 1725it [19:45,  1.45it/s]
# ######################################################################
# EPOCH:  14
# 1723it [19:34,  1.47it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# taggging loss, glyph loss
# 1.8523121980251744e-05 22.089139938354492
# 100% 22/22 [00:11<00:00,  2.00it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.0544 0.9686 0.9696 0.9691 0.9747
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 1725it [19:46,  1.45it/s]
# 100% 22/22 [00:10<00:00,  2.02it/s]
# ............................................................
# TEST: loss, precision, recall, f1, acc
# 0.0766 0.9605 0.9634 0.9619 0.9703
# =&==&==&==&==&==&==&==&==&==&==&==&==&==&==&=
# DEV: current best loss, precision, recall, f1, acc
# 0.0301 0.9697 0.9727 0.9712 0.9762
# TEST: current best loss, precision, recall, f1, acc
# 0.0766 0.9605 0.9634 0.9619 0.9703
# =&==&==&==&==&==&==&==&==&==&==&==&==&==&==&=

# %%
end = time.perf_counter()
elapsed = end-start
hours = elapsed//(60*60)
mins = (elapsed - hours*60*60)//60
secs = (elapsed - hours*60*60 - mins*60)
print("Time elapsed: %02d:%02d:%02d" % (hours,mins,secs))
# Out:
# Time elapsed: 04:23:00
