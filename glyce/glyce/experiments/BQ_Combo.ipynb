# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !pip install pypinyin pywubi zhconv overrides boto3
# !pip install torch-scatter -f https://pytorch-geometric.com/whl/torch-1.9.0+cu102.html
# !pip install torch-sparse -f https://pytorch-geometric.com/whl/torch-1.9.0+cu102.html
# !pip install torch-cluster -f https://pytorch-geometric.com/whl/torch-1.9.0+cu102.html
# !pip install torch-spline-conv -f https://pytorch-geometric.com/whl/torch-1.9.0+cu102.html
# !pip install torch-geometric
# Out:
# Collecting pypinyin
#   Downloading pypinyin-0.42.0-py2.py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 5.1 MB/s
# Collecting pywubi
#   Downloading pywubi-0.0.2-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 89.3 MB/s
# Collecting zhconv
#   Downloading zhconv-1.4.2.tar.gz (183 kB)
#      |████████████████████████████████| 183 kB 89.6 MB/s
# Collecting overrides
#   Downloading overrides-6.1.0-py3-none-any.whl (14 kB)
# Collecting boto3
#   Downloading boto3-1.18.26-py3-none-any.whl (131 kB)
#      |████████████████████████████████| 131 kB 73.5 MB/s
# Collecting typing-utils>=0.0.3
#   Downloading typing_utils-0.1.0-py3-none-any.whl (10 kB)
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting s3transfer<0.6.0,>=0.5.0
#   Downloading s3transfer-0.5.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 10.3 MB/s
# Collecting botocore<1.22.0,>=1.21.26
#   Downloading botocore-1.21.26-py3-none-any.whl (7.8 MB)
#      |████████████████████████████████| 7.8 MB 63.4 MB/s
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.22.0,>=1.21.26->boto3) (2.8.2)
# Collecting urllib3<1.27,>=1.25.4
#   Downloading urllib3-1.26.6-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 75.5 MB/s
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.22.0,>=1.21.26->boto3) (1.15.0)
# Building wheels for collected packages: zhconv
#   Building wheel for zhconv (setup.py) ... done
#   Created wheel for zhconv: filename=zhconv-1.4.2-py2.py3-none-any.whl size=181081 sha256=abb508207fc7dd807e18015b126796f3979a5d867fae799ba6c7d0c2d5318ad4
#   Stored in directory: /root/.cache/pip/wheels/10/31/84/fca23def9be1db201eeaa76f4ee50a7d64f6e20ee7b223cc4f
# Successfully built zhconv
# Installing collected packages: urllib3, jmespath, botocore, typing-utils, s3transfer, zhconv, pywubi, pypinyin, overrides, boto3
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.6 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed boto3-1.18.26 botocore-1.21.26 jmespath-0.10.0 overrides-6.1.0 pypinyin-0.42.0 pywubi-0.0.2 s3transfer-0.5.0 typing-utils-0.1.0 urllib3-1.26.6 zhconv-1.4.2
# Looking in links: https://pytorch-geometric.com/whl/torch-1.9.0+cu102.html
# Collecting torch-scatter
#   Downloading https://pytorch-geometric.com/whl/torch-1.9.0%2Bcu102/torch_scatter-2.0.8-cp37-cp37m-linux_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 3.6 MB/s
# Installing collected packages: torch-scatter
# Successfully installed torch-scatter-2.0.8
# Looking in links: https://pytorch-geometric.com/whl/torch-1.9.0+cu102.html
# Collecting torch-sparse
#   Downloading https://pytorch-geometric.com/whl/torch-1.9.0%2Bcu102/torch_sparse-0.6.11-cp37-cp37m-linux_x86_64.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 2.7 MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-sparse) (1.4.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scipy->torch-sparse) (1.19.5)
# Installing collected packages: torch-sparse
# Successfully installed torch-sparse-0.6.11
# Looking in links: https://pytorch-geometric.com/whl/torch-1.9.0+cu102.html
# Collecting torch-cluster
#   Downloading https://pytorch-geometric.com/whl/torch-1.9.0%2Bcu102/torch_cluster-1.5.9-cp37-cp37m-linux_x86_64.whl (926 kB)
#      |████████████████████████████████| 926 kB 2.7 MB/s
# Installing collected packages: torch-cluster
# Successfully installed torch-cluster-1.5.9
# Looking in links: https://pytorch-geometric.com/whl/torch-1.9.0+cu102.html
# Collecting torch-spline-conv
#   Downloading https://pytorch-geometric.com/whl/torch-1.9.0%2Bcu102/torch_spline_conv-1.2.1-cp37-cp37m-linux_x86_64.whl (382 kB)
#      |████████████████████████████████| 382 kB 2.8 MB/s
# Installing collected packages: torch-spline-conv
# Successfully installed torch-spline-conv-1.2.1
# Collecting torch-geometric
#   Downloading torch_geometric-1.7.2.tar.gz (222 kB)
#      |████████████████████████████████| 222 kB 5.1 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.19.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (4.62.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.4.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (2.6.2)
# Requirement already satisfied: python-louvain in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (0.15)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (0.22.2.post1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (2.23.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.1.5)
# Collecting rdflib
#   Downloading rdflib-6.0.0-py3-none-any.whl (376 kB)
#      |████████████████████████████████| 376 kB 62.0 MB/s
# Requirement already satisfied: googledrivedownloader in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (2.11.3)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (2.4.7)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->torch-geometric) (2.0.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->torch-geometric) (1.15.0)
# Collecting isodate
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 3.9 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric) (57.4.0)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 66.6 MB/s
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (3.0.4)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric) (1.0.1)
# Building wheels for collected packages: torch-geometric
#   Building wheel for torch-geometric (setup.py) ... done
#   Created wheel for torch-geometric: filename=torch_geometric-1.7.2-py3-none-any.whl size=388143 sha256=cdbec5de2ce14949ecc939d8e09b0519909e4f5b755fbc1ffa16832dfa5c1259
#   Stored in directory: /root/.cache/pip/wheels/55/93/b6/2eeb0465afe89aee74d7a07a606e9770466d7565abd45a99d5
# Successfully built torch-geometric
# Installing collected packages: urllib3, isodate, rdflib, torch-geometric
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.6
#     Uninstalling urllib3-1.26.6:
#       Successfully uninstalled urllib3-1.26.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed isodate-0.6.0 rdflib-6.0.0 torch-geometric-1.7.2 urllib3-1.25.11

# %%
import time
import torch
print(torch.__version__)
print(torch.cuda.get_device_name(0))
start = time.perf_counter()
# Out:
# 1.9.0+cu102
# Tesla P100-PCIE-16GB

# %%
# !python3 "/content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/bin/run_bert_combo_classifier.py" \
--data_sign bq \
--task_name clf \
--config_path "/content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/configs/combo_bert.json" \
--data_dir "/content/gdrive/MyDrive/Colab Data/Chinese Characters/sent_pair/bq" \
--output_name "/content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/my_export_models/bq combo.bin" \
--bert_model "/content/gdrive/MyDrive/Colab Data/Chinese Characters/chinese_L-12_H-768_A-12" \
--graph_path "/content/gdrive/MyDrive/Colab Data/Chinese Characters/graphsDictOrder.pickle" \
--checkpoint 4167 \
--seed 8008 \
--max_seq_length 150 \
--do_train \
--do_eval \
--train_batch_size 24 \
--dev_batch_size 24 \
--test_batch_size 24 \
--learning_rate 3e-5 \
--num_train_epochs 15 \
--gcn_hidden 300 \
--k 30 \
--num_features 6 \
--warmup_proportion 0 \
--pretrained_graph "yes" \
--batch_norm "layer" \
--graph_dict "/content/gdrive/MyDrive/Colab Data/Chinese Characters/unsupGraphModelDict300.bin" \
--training_strat "bert-glyce-joint"
# Out:
# check the root_path of this repo
# /content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce
# /content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce
# PATH to render.py
# =*=*=*=*=*=*=*=*=*=*
# /content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce
# PRINT default FONT PATH
# ********************
# /content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/fonts
# ********************
# Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex.
# Please Notice that Merge the args_dict and json_config ... ...
# Update the config from args input
# {
#   "glyph_ratio": 0.1,
#   "glyph_decay": 0.1,
#   "glyph_warmup": 0,
#   "bert_frozen": "true",
#   "hidden_size": 888,
#   "hidden_dropout_prob": 0.0,
#   "classifier_sign": "single_linear",
#   "bert_config": {
#     "attention_probs_dropout_prob": 0.1,
#     "directionality": "bidi",
#     "hidden_act": "gelu",
#     "hidden_dropout_prob": 0.1,
#     "hidden_size": 768,
#     "initializer_range": 0.02,
#     "intermediate_size": 3072,
#     "max_position_embeddings": 512,
#     "num_attention_heads": 12,
#     "num_hidden_layers": 12,
#     "pooler_fc_size": 768,
#     "pooler_num_attention_heads": 12,
#     "pooler_num_fc_layers": 3,
#     "pooler_size_per_head": 128,
#     "pooler_type": "first_token_transform",
#     "type_vocab_size": 2,
#     "vocab_size": 21128
#   },
#   "glyph_config": {
#     "hidden_dropout_prob": 0.5,
#     "max_position_embeddings": 512,
#     "bert_model": "/content/gdrive/MyDrive/Colab Data/Chinese Characters/chinese_L-12_H-768_A-12",
#     "char2word_dim": 0,
#     "char_drop": 0.5,
#     "char_embsize": 0,
#     "cnn_dropout": 0.5,
#     "dropout": 0.5,
#     "fc_merge": false,
#     "font_channels": 1,
#     "font_name": "cjk/NotoSansCJKsc-Regular.otf",
#     "font_normalize": false,
#     "font_size": 18,
#     "glyph_cnn_type": "Yuxian8",
#     "glyph_embsize": 96,
#     "glyph_groups": 8,
#     "idx2char": null,
#     "idx2word": null,
#     "level": "char",
#     "loss_mask_ids": [
#       0,
#       101,
#       102
#     ],
#     "num_fonts_concat": 1,
#     "output_size": 96,
#     "pretrained_char_embedding": "",
#     "pretrained_word_embedding": "",
#     "random_erase": false,
#     "random_fonts": 0,
#     "subchar_embsize": 512,
#     "subchar_type": "",
#     "use_batch_norm": true,
#     "use_highway": false,
#     "use_layer_norm": false,
#     "use_maxpool": true,
#     "use_traditional": false,
#     "word_embsize": 1024,
#     "yuxian_merge": false,
#     "font_names": []
#   },
#   "graph_config": {
#     "hidden_dropout_prob": 0.5,
#     "max_position_embeddings": 512,
#     "bert_model": "/content/gdrive/MyDrive/Colab Data/Chinese Characters/chinese_L-12_H-768_A-12",
#     "graph_path": "/content/gdrive/MyDrive/Colab Data/Chinese Characters/graphsDictOrder.pickle",
#     "char2word_dim": 0,
#     "char_drop": 0.5,
#     "char_embsize": 0,
#     "gcn_dropout": 0.5,
#     "dropout": 0.5,
#     "num_features": 6,
#     "gcn_hidden": 300,
#     "k": 30,
#     "gcn_layer": "SAGE",
#     "fc_merge": false,
#     "font_channels": 1,
#     "font_name": "cjk/NotoSansCJKsc-Regular.otf",
#     "font_normalize": false,
#     "font_size": 18,
#     "graph_cnn_type": "Yuxian8",
#     "graph_embsize": 24,
#     "graph_groups": 8,
#     "idx2char": null,
#     "idx2word": null,
#     "level": "char",
#     "loss_mask_ids": [
#       0,
#       101,
#       102
#     ],
#     "num_fonts_concat": 1,
#     "output_size": 24,
#     "pretrained_char_embedding": "",
#     "pretrained_word_embedding": "",
#     "random_erase": false,
#     "random_fonts": 0,
#     "subchar_embsize": 512,
#     "subchar_type": "",
#     "use_batch_norm": true,
#     "use_highway": false,
#     "use_layer_norm": false,
#     "use_maxpool": true,
#     "use_traditional": false,
#     "word_embsize": 1024,
#     "yuxian_merge": false,
#     "pool": "sort",
#     "graph_dict": "/content/gdrive/MyDrive/Colab Data/Chinese Characters/unsupGraphModelDict300.bin",
#     "pretrained_graph": "yes",
#     "batch_norm": "layer"
#   },
#   "transformer_config": {
#     "max_position_embeddings": 512,
#     "attention_probs_dropout_prob": 0.5,
#     "directionality": "bidi",
#     "hidden_act": "gelu",
#     "hidden_dropout_prob": 0.5,
#     "hidden_size": 888,
#     "initializer_range": 0.02,
#     "intermediate_size": 3552,
#     "num_attention_heads": 24,
#     "num_hidden_layers": 2,
#     "pooler_fc_size": 888,
#     "pooler_num_attention_heads": 12,
#     "pooler_num_fc_layers": 2,
#     "pooler_size_per_head": 256,
#     "pooler_type": "first_token_transform",
#     "type_vocab_size": 2,
#     "vocab_size": 21128
#   },
#   "config_path": "/content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/configs/combo_bert.json",
#   "data_dir": "/content/gdrive/MyDrive/Colab Data/Chinese Characters/sent_pair/bq",
#   "bert_model": "/content/gdrive/MyDrive/Colab Data/Chinese Characters/chinese_L-12_H-768_A-12",
#   "task_name": "clf",
#   "cuda": true,
#   "max_seq_length": 150,
#   "do_train": true,
#   "do_eval": true,
#   "train_batch_size": 24,
#   "dev_batch_size": 24,
#   "checkpoint": 4167,
#   "test_batch_size": 24,
#   "learning_rate": 3e-05,
#   "num_train_epochs": 15.0,
#   "warmup_proportion": 0.0,
#   "local_rank": -1,
#   "gradient_accumulation_steps": 1,
#   "seed": 8008,
#   "nworkers": 1,
#   "step": 1,
#   "export_model": true,
#   "output_name": "/content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/my_export_models/bq combo/real_1.bin",
#   "data_sign": "bq",
#   "residual": "no",
#   "training_strat": "bert-glyce-joint",
#   "transformer": "yes"
# }
# 99999it [00:16, 6084.22it/s]
# 9999it [00:02, 4718.00it/s]
# 9999it [00:01, 6413.18it/s]
# !=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!
# Please notice that the bert model if frozen
# the loaded weights of models is
# /content/gdrive/MyDrive/Colab Data/Chinese Characters/chinese_L-12_H-768_A-12
# !-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!
#
# Training Bert...
# ######################################################################
# EPOCH:  0
# 0it [00:00, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   warnings.warn(warning.format(ret))
# /content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/utils/optimization.py:142: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:1025.)
#   next_m.mul_(beta1).add_(1 - beta1, grad)
# 4165it [54:46,  1.27it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# classification loss, glyph loss
# 0.3422417640686035 12.85206127166748
# 100% 417/417 [05:06<00:00,  1.36it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.4996 0.8348834883488349 0.8348834883488349 0.8348834883488349 0.8348834883488349
# 100% 417/417 [05:07<00:00,  1.35it/s]
# ............................................................
# TEST: loss, precision, recall, f1, acc
# 0.5136 0.823982398239824 0.823982398239824 0.823982398239824 0.823982398239824
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 4167it [1:05:03,  1.07it/s]
# ######################################################################
# EPOCH:  1
# 4165it [54:21,  1.20it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# classification loss, glyph loss
# 0.08864494413137436 11.387761116027832
# 100% 417/417 [05:07<00:00,  1.36it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.4052 0.8455845584558456 0.8455845584558456 0.8455845584558456 0.8455845584558456
# 100% 417/417 [05:07<00:00,  1.35it/s]
# ............................................................
# TEST: loss, precision, recall, f1, acc
# 0.4247 0.8383838383838383 0.8383838383838383 0.8383838383838383 0.8383838383838383
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 4167it [1:04:40,  1.07it/s]
# ######################################################################
# EPOCH:  2
# 4165it [54:20,  1.28it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# classification loss, glyph loss
# 0.023740598931908607 11.365530014038086
# 100% 417/417 [05:07<00:00,  1.36it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.4987 0.8432843284328433 0.8432843284328433 0.8432843284328433 0.8432843284328433
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 4167it [59:29,  1.17it/s]
# ######################################################################
# EPOCH:  3
# 4165it [54:17,  1.29it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# classification loss, glyph loss
# 0.028315899893641472 11.449258804321289
# 100% 417/417 [05:07<00:00,  1.36it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.5839 0.843084308430843 0.843084308430843 0.843084308430843 0.843084308430843
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 4167it [59:26,  1.17it/s]
# ######################################################################
# EPOCH:  4
# 4165it [54:18,  1.24it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# classification loss, glyph loss
# 0.004847727715969086 11.649893760681152
# 100% 417/417 [05:06<00:00,  1.36it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.5941 0.849084908490849 0.849084908490849 0.849084908490849 0.849084908490849
# 100% 417/417 [05:07<00:00,  1.35it/s]
# ............................................................
# TEST: loss, precision, recall, f1, acc
# 0.6038 0.8415841584158416 0.8415841584158416 0.8415841584158416 0.8415841584158416
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 4167it [1:04:36,  1.07it/s]
#
# Training Combo...
# ######################################################################
# EPOCH:  5
# 4165it [41:43,  1.67it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# classification loss, glyph loss
# 0.0004964243853464723 11.084598541259766
# 100% 417/417 [05:07<00:00,  1.35it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.6814 0.843984398439844 0.843984398439844 0.8439843984398439 0.843984398439844
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 4167it [46:52,  1.48it/s]
# ######################################################################
# EPOCH:  6
# 4165it [41:39,  1.68it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# classification loss, glyph loss
# 0.0011227665236219764 11.105804443359375
# 100% 417/417 [05:07<00:00,  1.36it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.7831 0.8477847784778478 0.8477847784778478 0.8477847784778478 0.8477847784778478
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 4167it [46:48,  1.48it/s]
# ######################################################################
# EPOCH:  7
# 4165it [41:38,  1.68it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# classification loss, glyph loss
# 0.0003085556672886014 11.066397666931152
# 100% 417/417 [05:07<00:00,  1.36it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.7348 0.8467846784678468 0.8467846784678468 0.8467846784678468 0.8467846784678468
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 4167it [46:46,  1.48it/s]
# ######################################################################
# EPOCH:  8
# 4165it [41:37,  1.68it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# classification loss, glyph loss
# 0.001989927375689149 11.075163841247559
# 100% 417/417 [05:07<00:00,  1.35it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.8562 0.8481848184818482 0.8481848184818482 0.8481848184818482 0.8481848184818482
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 4167it [46:46,  1.48it/s]
# ######################################################################
# EPOCH:  9
# 4165it [41:40,  1.68it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# classification loss, glyph loss
# 0.0001577673974679783 11.02064037322998
# 100% 417/417 [05:07<00:00,  1.36it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 1.014 0.8468846884688469 0.8468846884688469 0.8468846884688469 0.8468846884688469
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 4167it [46:48,  1.48it/s]
#
# Training Both...
# ######################################################################
# EPOCH:  10
# 4165it [59:48,  1.16it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# classification loss, glyph loss
# 0.000906551256775856 11.169707298278809
# 100% 417/417 [05:07<00:00,  1.36it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.7538 0.844984498449845 0.844984498449845 0.844984498449845 0.844984498449845
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 4167it [1:04:57,  1.07it/s]
# ######################################################################
# EPOCH:  11
# 4165it [59:47,  1.16it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# classification loss, glyph loss
# 4.594452093442669e-06 11.015986442565918
# 100% 417/417 [05:07<00:00,  1.36it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.9861 0.8484848484848485 0.8484848484848485 0.8484848484848486 0.8484848484848485
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 4167it [1:04:56,  1.07it/s]
# ######################################################################
# EPOCH:  12
# 4165it [59:46,  1.16it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# classification loss, glyph loss
# 0.0014440612867474556 11.118560791015625
# 100% 417/417 [05:07<00:00,  1.35it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.9113 0.8471847184718472 0.8471847184718472 0.8471847184718472 0.8471847184718472
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 4167it [1:04:56,  1.07it/s]
# ######################################################################
# EPOCH:  13
# 4165it [59:55,  1.16it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# classification loss, glyph loss
# 2.3394779873342486e-06 11.003618240356445
# 100% 417/417 [05:09<00:00,  1.35it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 1.2704 0.8472847284728473 0.8472847284728473 0.8472847284728473 0.8472847284728473
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 4167it [1:05:06,  1.07it/s]
# ######################################################################
# EPOCH:  14
# 4165it [1:00:05,  1.16it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# classification loss, glyph loss
# 8.155770956363995e-06 11.102704048156738
# 100% 417/417 [05:10<00:00,  1.34it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 1.2595 0.848984898489849 0.848984898489849 0.848984898489849 0.848984898489849
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 4167it [1:05:17,  1.06it/s]
# 100% 417/417 [05:09<00:00,  1.35it/s]
# ............................................................
# TEST: loss, precision, recall, f1, acc
# 1.278 0.8433843384338434 0.8433843384338434 0.8433843384338433 0.8433843384338434
# =&==&==&==&==&==&==&==&==&==&==&==&==&==&==&=
# DEV: current best loss, precision, recall, f1, acc
# 0.5941 0.849084908490849 0.849084908490849 0.849084908490849 0.849084908490849
# TEST: current best loss, precision, recall, f1, acc
# 1.278 0.8433843384338434 0.8433843384338434 0.8433843384338433 0.8433843384338434
# =&==&==&==&==&==&==&==&==&==&==&==&==&==&==&=

# %%
end = time.perf_counter()
elapsed = end-start
hours = elapsed//(60*60)
mins = (elapsed - hours*60*60)//60
secs = (elapsed - hours*60*60 - mins*60)
print("Time elapsed: %02d:%02d:%02d" % (hours,mins,secs))
# Out:
# Time elapsed: 14:39:18
