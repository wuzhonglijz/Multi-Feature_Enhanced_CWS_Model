# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !pip install pypinyin pywubi zhconv overrides boto3
# !pip install torch-scatter -f https://pytorch-geometric.com/whl/torch-1.9.0+cu102.html
# !pip install torch-sparse -f https://pytorch-geometric.com/whl/torch-1.9.0+cu102.html
# !pip install torch-cluster -f https://pytorch-geometric.com/whl/torch-1.9.0+cu102.html
# !pip install torch-spline-conv -f https://pytorch-geometric.com/whl/torch-1.9.0+cu102.html
# !pip install torch-geometric==1.7.2
# Out:
# Collecting pypinyin
#   Downloading pypinyin-0.42.0-py2.py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 4.1 MB/s
# Collecting pywubi
#   Downloading pywubi-0.0.2-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 83.8 MB/s
# Collecting zhconv
#   Downloading zhconv-1.4.2.tar.gz (183 kB)
#      |████████████████████████████████| 183 kB 73.1 MB/s
# Collecting overrides
#   Downloading overrides-6.1.0-py3-none-any.whl (14 kB)
# Collecting boto3
#   Downloading boto3-1.18.42-py3-none-any.whl (131 kB)
#      |████████████████████████████████| 131 kB 68.8 MB/s
# Collecting typing-utils>=0.0.3
#   Downloading typing_utils-0.1.0-py3-none-any.whl (10 kB)
# Collecting botocore<1.22.0,>=1.21.42
#   Downloading botocore-1.21.42-py3-none-any.whl (7.9 MB)
#      |████████████████████████████████| 7.9 MB 64.1 MB/s
# Collecting s3transfer<0.6.0,>=0.5.0
#   Downloading s3transfer-0.5.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 9.0 MB/s
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting urllib3<1.27,>=1.25.4
#   Downloading urllib3-1.26.6-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 78.8 MB/s
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.22.0,>=1.21.42->boto3) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.22.0,>=1.21.42->boto3) (1.15.0)
# Building wheels for collected packages: zhconv
#   Building wheel for zhconv (setup.py) ... done
#   Created wheel for zhconv: filename=zhconv-1.4.2-py2.py3-none-any.whl size=181081 sha256=b2a51918d21a8d5b11d902856ae6c4c1d41976df3d5aeb0348d622cc88953005
#   Stored in directory: /root/.cache/pip/wheels/10/31/84/fca23def9be1db201eeaa76f4ee50a7d64f6e20ee7b223cc4f
# Successfully built zhconv
# Installing collected packages: urllib3, jmespath, botocore, typing-utils, s3transfer, zhconv, pywubi, pypinyin, overrides, boto3
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.6 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed boto3-1.18.42 botocore-1.21.42 jmespath-0.10.0 overrides-6.1.0 pypinyin-0.42.0 pywubi-0.0.2 s3transfer-0.5.0 typing-utils-0.1.0 urllib3-1.26.6 zhconv-1.4.2
# Looking in links: https://pytorch-geometric.com/whl/torch-1.9.0+cu102.html
# Collecting torch-scatter
#   Downloading https://data.pyg.org/whl/torch-1.9.0%2Bcu102/torch_scatter-2.0.8-cp37-cp37m-linux_x86_64.whl (8.0 MB)
#      |████████████████████████████████| 8.0 MB 4.1 MB/s
# Installing collected packages: torch-scatter
# Successfully installed torch-scatter-2.0.8
# Looking in links: https://pytorch-geometric.com/whl/torch-1.9.0+cu102.html
# Collecting torch-sparse
#   Downloading https://data.pyg.org/whl/torch-1.9.0%2Bcu102/torch_sparse-0.6.12-cp37-cp37m-linux_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 4.1 MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-sparse) (1.4.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scipy->torch-sparse) (1.19.5)
# Installing collected packages: torch-sparse
# Successfully installed torch-sparse-0.6.12
# Looking in links: https://pytorch-geometric.com/whl/torch-1.9.0+cu102.html
# Collecting torch-cluster
#   Downloading https://data.pyg.org/whl/torch-1.9.0%2Bcu102/torch_cluster-1.5.9-cp37-cp37m-linux_x86_64.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 3.7 MB/s
# Installing collected packages: torch-cluster
# Successfully installed torch-cluster-1.5.9
# Looking in links: https://pytorch-geometric.com/whl/torch-1.9.0+cu102.html
# Collecting torch-spline-conv
#   Downloading https://data.pyg.org/whl/torch-1.9.0%2Bcu102/torch_spline_conv-1.2.1-cp37-cp37m-linux_x86_64.whl (677 kB)
#      |████████████████████████████████| 677 kB 3.7 MB/s
# Installing collected packages: torch-spline-conv
# Successfully installed torch-spline-conv-1.2.1
# Collecting torch-geometric==1.7.2
#   Downloading torch_geometric-1.7.2.tar.gz (222 kB)
#      |████████████████████████████████| 222 kB 4.2 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.7.2) (1.19.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.7.2) (4.62.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.7.2) (1.4.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.7.2) (2.6.2)
# Requirement already satisfied: python-louvain in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.7.2) (0.15)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.7.2) (0.22.2.post1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.7.2) (2.23.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.7.2) (1.1.5)
# Collecting rdflib
#   Downloading rdflib-6.0.0-py3-none-any.whl (376 kB)
#      |████████████████████████████████| 376 kB 69.8 MB/s
# Requirement already satisfied: googledrivedownloader in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.7.2) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.7.2) (2.11.3)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.7.2) (2.4.7)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->torch-geometric==1.7.2) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.7.2) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.7.2) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->torch-geometric==1.7.2) (1.15.0)
# Collecting isodate
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 4.4 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric==1.7.2) (57.4.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.7.2) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.7.2) (2.10)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 77.0 MB/s
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.7.2) (2021.5.30)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric==1.7.2) (1.0.1)
# Building wheels for collected packages: torch-geometric
#   Building wheel for torch-geometric (setup.py) ... done
#   Created wheel for torch-geometric: filename=torch_geometric-1.7.2-py3-none-any.whl size=388143 sha256=1cba93a419ff5bfeb367986b473ead8583894986aba1ef58378262d749ff8ea6
#   Stored in directory: /root/.cache/pip/wheels/55/93/b6/2eeb0465afe89aee74d7a07a606e9770466d7565abd45a99d5
# Successfully built torch-geometric
# Installing collected packages: urllib3, isodate, rdflib, torch-geometric
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.6
#     Uninstalling urllib3-1.26.6:
#       Successfully uninstalled urllib3-1.26.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed isodate-0.6.0 rdflib-6.0.0 torch-geometric-1.7.2 urllib3-1.25.11

# %%
import time
import torch
print(torch.__version__)
print(torch.cuda.get_device_name(0))
start = time.perf_counter()
# Out:
# 1.9.0+cu102
# Tesla T4

# %%
# !python3 "/content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/bin/run_bert_graph_classifier.py" \
--data_sign bq \
--task_name clf \
--config_path "/content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/configs/graph_bert.json" \
--data_dir "/content/gdrive/MyDrive/Colab Data/Chinese Characters/sent_pair/bq" \
--output_name "/content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/my_export_models/bq graph.bin" \
--bert_model "/content/gdrive/MyDrive/Colab Data/Chinese Characters/chinese_L-12_H-768_A-12" \
--graph_path "/content/gdrive/MyDrive/Colab Data/Chinese Characters/graphsDictOrder.pickle" \
--checkpoint 4166 \
--seed 8008 \
--max_seq_length 64 \
--do_train \
--do_eval \
--train_batch_size 24 \
--dev_batch_size 24 \
--test_batch_size 24 \
--learning_rate 2e-5 \
--num_train_epochs 15 \
--gcn_hidden 300 \
--k 30 \
--graph_embsize 24 \
--output_size 24 \
--pooler_fc_size 792 \
--hidden_size 792 \
--transformer_hidden_size 792 \
--num_features 6 \
--warmup_proportion 0 \
--pretrained_graph "yes" \
--batch_norm "layer" \
--graph_dict "/content/gdrive/MyDrive/Colab Data/Chinese Characters/unsupGraphModelDict300.bin" \
--training_strat "bert-glyce-joint"
# Out:
# check the root_path of this repo
# /content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce
# /content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce
# PATH to render.py
# =*=*=*=*=*=*=*=*=*=*
# /content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce
# PRINT default FONT PATH
# ********************
# /content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/fonts
# ********************
# Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex.
# Please Notice that Merge the args_dict and json_config ... ...
# Update the config from args input
# Update the config from args input
# {
#   "glyph_ratio": 0.1,
#   "glyph_decay": 0.1,
#   "glyph_warmup": 0,
#   "bert_frozen": "true",
#   "hidden_size": 792,
#   "hidden_dropout_prob": 0.0,
#   "classifier_sign": "single_linear",
#   "clip_grad": 1.0,
#   "bert_config": {
#     "attention_probs_dropout_prob": 0.1,
#     "directionality": "bidi",
#     "hidden_act": "gelu",
#     "hidden_dropout_prob": 0.1,
#     "hidden_size": 768,
#     "initializer_range": 0.02,
#     "intermediate_size": 3072,
#     "max_position_embeddings": 512,
#     "num_attention_heads": 12,
#     "num_hidden_layers": 12,
#     "pooler_fc_size": 768,
#     "pooler_num_attention_heads": 12,
#     "pooler_num_fc_layers": 3,
#     "pooler_size_per_head": 128,
#     "pooler_type": "first_token_transform",
#     "type_vocab_size": 2,
#     "vocab_size": 21128
#   },
#   "graph_config": {
#     "hidden_dropout_prob": 0.5,
#     "max_position_embeddings": 512,
#     "bert_model": "/content/gdrive/MyDrive/Colab Data/Chinese Characters/chinese_L-12_H-768_A-12",
#     "graph_path": "/content/gdrive/MyDrive/Colab Data/Chinese Characters/graphsDictOrder.pickle",
#     "char2word_dim": 0,
#     "char_drop": 0.5,
#     "char_embsize": 0,
#     "gcn_dropout": 0.5,
#     "dropout": 0.5,
#     "num_features": 6,
#     "gcn_hidden": 300,
#     "k": 30,
#     "gcn_layer": "SAGE",
#     "fc_merge": false,
#     "font_channels": 1,
#     "font_name": "cjk/NotoSansCJKsc-Regular.otf",
#     "font_normalize": false,
#     "font_size": 18,
#     "graph_cnn_type": "Yuxian8",
#     "graph_embsize": 24,
#     "graph_groups": 8,
#     "idx2char": null,
#     "idx2word": null,
#     "level": "char",
#     "loss_mask_ids": [
#       0,
#       101,
#       102
#     ],
#     "num_fonts_concat": 1,
#     "output_size": 24,
#     "pretrained_char_embedding": "",
#     "pretrained_word_embedding": "",
#     "random_erase": false,
#     "random_fonts": 0,
#     "subchar_embsize": 512,
#     "subchar_type": "",
#     "use_batch_norm": true,
#     "use_highway": false,
#     "use_layer_norm": false,
#     "use_maxpool": true,
#     "use_traditional": false,
#     "word_embsize": 1024,
#     "yuxian_merge": false,
#     "pool": "sort",
#     "graph_dict": "/content/gdrive/MyDrive/Colab Data/Chinese Characters/unsupGraphModelDict300.bin",
#     "pretrained_graph": "yes",
#     "batch_norm": "layer"
#   },
#   "transformer_config": {
#     "max_position_embeddings": 512,
#     "attention_probs_dropout_prob": 0.5,
#     "directionality": "bidi",
#     "hidden_act": "gelu",
#     "hidden_dropout_prob": 0.5,
#     "hidden_size": 792,
#     "initializer_range": 0.02,
#     "intermediate_size": 6144,
#     "num_attention_heads": 24,
#     "num_hidden_layers": 2,
#     "pooler_fc_size": 792,
#     "pooler_num_attention_heads": 12,
#     "pooler_num_fc_layers": 2,
#     "pooler_size_per_head": 256,
#     "pooler_type": "first_token_transform",
#     "type_vocab_size": 2,
#     "vocab_size": 21128
#   },
#   "config_path": "/content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/configs/graph_bert.json",
#   "data_dir": "/content/gdrive/MyDrive/Colab Data/Chinese Characters/sent_pair/bq",
#   "bert_model": "/content/gdrive/MyDrive/Colab Data/Chinese Characters/chinese_L-12_H-768_A-12",
#   "task_name": "clf",
#   "cuda": true,
#   "max_seq_length": 64,
#   "do_train": true,
#   "do_eval": true,
#   "train_batch_size": 24,
#   "dev_batch_size": 24,
#   "checkpoint": 4166,
#   "test_batch_size": 24,
#   "learning_rate": 2e-05,
#   "num_train_epochs": 15.0,
#   "warmup_proportion": 0.0,
#   "local_rank": -1,
#   "gradient_accumulation_steps": 1,
#   "seed": 8008,
#   "nworkers": 1,
#   "step": 1,
#   "export_model": true,
#   "output_name": "/content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/my_export_models/bq graph/real_2.bin",
#   "data_sign": "bq",
#   "residual": "no",
#   "training_strat": "bert-glyce-joint",
#   "transformer": "yes"
# }
# 99999it [00:16, 6222.50it/s]
# 9999it [00:01, 5292.05it/s]
# 9999it [00:01, 6292.16it/s]
# !=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!
# Please notice that the bert model if frozen
# the loaded weights of models is
# /content/gdrive/MyDrive/Colab Data/Chinese Characters/chinese_L-12_H-768_A-12
# !-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!
#
# Training Bert...
# ######################################################################
# EPOCH:  0
# 0it [00:00, ?it/s]/content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/utils/optimization.py:142: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:1025.)
#   next_m.mul_(beta1).add_(1 - beta1, grad)
# 4164it [42:16,  1.65it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# classification loss
# 0.15397056937217712
# 100% 417/417 [03:09<00:00,  2.21it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.4097 0.8484848484848485 0.8484848484848485 0.8484848484848486 0.8484848484848485
# 100% 417/417 [03:09<00:00,  2.20it/s]
# ............................................................
# TEST: loss, precision, recall, f1, acc
# 0.4272 0.843984398439844 0.843984398439844 0.8439843984398439 0.843984398439844
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 4167it [48:39,  1.43it/s]
# ######################################################################
# EPOCH:  1
# 4164it [42:04,  1.66it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# classification loss
# 0.04661478474736214
# 100% 417/417 [03:09<00:00,  2.20it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.4483 0.8475847584758476 0.8475847584758476 0.8475847584758476 0.8475847584758476
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 4167it [45:16,  1.53it/s]
# ######################################################################
# EPOCH:  2
# 4164it [42:07,  1.65it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# classification loss
# 0.00791859533637762
# 100% 417/417 [03:09<00:00,  2.21it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.5094 0.8384838483848385 0.8384838483848385 0.8384838483848385 0.8384838483848385
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 4167it [45:18,  1.53it/s]
# ######################################################################
# EPOCH:  3
# 4164it [42:03,  1.66it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# classification loss
# 0.3615550696849823
# 100% 417/417 [03:09<00:00,  2.20it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.7595 0.8330833083308331 0.8330833083308331 0.8330833083308331 0.8330833083308331
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 4167it [45:14,  1.53it/s]
# ######################################################################
# EPOCH:  4
# 4164it [42:05,  1.61it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# classification loss
# 0.07479073852300644
# 100% 417/417 [03:09<00:00,  2.20it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.6699 0.8509850985098509 0.8509850985098509 0.8509850985098509 0.8509850985098509
# 100% 417/417 [03:09<00:00,  2.20it/s]
# ............................................................
# TEST: loss, precision, recall, f1, acc
# 0.7064 0.8454845484548454 0.8454845484548454 0.8454845484548453 0.8454845484548454
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 4167it [48:28,  1.43it/s]
#
# Training Graph...
# ######################################################################
# EPOCH:  5
# 4164it [32:01,  2.21it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# classification loss
# 0.008795151486992836
# 100% 417/417 [03:09<00:00,  2.20it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.7546 0.8500850085008501 0.8500850085008501 0.8500850085008501 0.8500850085008501
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 4167it