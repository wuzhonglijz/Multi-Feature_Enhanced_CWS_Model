# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !pip install pypinyin pywubi zhconv overrides boto3
# !pip install torch-scatter -f https://pytorch-geometric.com/whl/torch-1.9.0+cu102.html
# !pip install torch-sparse -f https://pytorch-geometric.com/whl/torch-1.9.0+cu102.html
# !pip install torch-cluster -f https://pytorch-geometric.com/whl/torch-1.9.0+cu102.html
# !pip install torch-spline-conv -f https://pytorch-geometric.com/whl/torch-1.9.0+cu102.html
# !pip install torch-geometric
# Out:
# Requirement already satisfied: pypinyin in /usr/local/lib/python3.7/dist-packages (0.42.0)
# Requirement already satisfied: pywubi in /usr/local/lib/python3.7/dist-packages (0.0.2)
# Requirement already satisfied: zhconv in /usr/local/lib/python3.7/dist-packages (1.4.2)
# Requirement already satisfied: overrides in /usr/local/lib/python3.7/dist-packages (6.1.0)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.7/dist-packages (1.18.25)
# Requirement already satisfied: typing-utils>=0.0.3 in /usr/local/lib/python3.7/dist-packages (from overrides) (0.1.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from boto3) (0.10.0)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from boto3) (0.5.0)
# Requirement already satisfied: botocore<1.22.0,>=1.21.25 in /usr/local/lib/python3.7/dist-packages (from boto3) (1.21.25)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/lib/python3.7/dist-packages (from botocore<1.22.0,>=1.21.25->boto3) (1.25.11)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.22.0,>=1.21.25->boto3) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.22.0,>=1.21.25->boto3) (1.15.0)
# Looking in links: https://pytorch-geometric.com/whl/torch-1.9.0+cu102.html
# Requirement already satisfied: torch-scatter in /usr/local/lib/python3.7/dist-packages (2.0.8)
# Looking in links: https://pytorch-geometric.com/whl/torch-1.9.0+cu102.html
# Requirement already satisfied: torch-sparse in /usr/local/lib/python3.7/dist-packages (0.6.11)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-sparse) (1.4.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scipy->torch-sparse) (1.19.5)
# Looking in links: https://pytorch-geometric.com/whl/torch-1.9.0+cu102.html
# Requirement already satisfied: torch-cluster in /usr/local/lib/python3.7/dist-packages (1.5.9)
# Looking in links: https://pytorch-geometric.com/whl/torch-1.9.0+cu102.html
# Requirement already satisfied: torch-spline-conv in /usr/local/lib/python3.7/dist-packages (1.2.1)
# Requirement already satisfied: torch-geometric in /usr/local/lib/python3.7/dist-packages (1.7.2)
# Requirement already satisfied: rdflib in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (6.0.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (4.62.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.1.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (2.23.0)
# Requirement already satisfied: googledrivedownloader in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (0.4)
# Requirement already satisfied: python-louvain in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (0.15)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.19.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (2.4.7)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (2.11.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (0.22.2.post1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.4.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (2.6.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->torch-geometric) (2.0.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->torch-geometric) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric) (57.4.0)
# Requirement already satisfied: isodate in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric) (0.6.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (2021.5.30)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric) (1.0.1)

# %%
import time
import torch
print(torch.__version__)
print(torch.cuda.get_device_name(0))
start = time.perf_counter()
# Out:
# 1.9.0+cu102
# Tesla P100-PCIE-16GB

# %%
# !python3 "/content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/bin/run_bert_graph_classifier.py" \
--data_sign fudan \
--task_name clf \
--config_path "/content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/configs/graph_bert.json" \
--data_dir "/content/gdrive/MyDrive/Colab Data/Chinese Characters/sent_cls/fudan" \
--output_name "/content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/my_export_models/fudan graph.bin" \
--bert_model "/content/gdrive/MyDrive/Colab Data/Chinese Characters/chinese_L-12_H-768_A-12" \
--graph_path "/content/gdrive/MyDrive/Colab Data/Chinese Characters/graphsDictOrder.pickle" \
--checkpoint 153 \
--seed 8008 \
--max_seq_length 128 \
--do_train \
--do_eval \
--train_batch_size 24 \
--dev_batch_size 24 \
--test_batch_size 24 \
--learning_rate 3e-5 \
--num_train_epochs 15 \
--gcn_hidden 300 \
--k 30 \
--graph_embsize 24 \
--output_size 24 \
--pooler_fc_size 792 \
--transformer_hidden_size 792 \
--hidden_size 792 \
--num_features 6 \
--warmup_proportion 0 \
--batch_norm "layer" \
--pretrained_graph "no" \
--graph_dict "/content/gdrive/MyDrive/Colab Data/Chinese Characters/unsupGraphModelDict300.bin" \
--training_strat "bert-glyce-joint"
# Out:
# check the root_path of this repo
# /content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce
# /content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce
# PATH to render.py
# =*=*=*=*=*=*=*=*=*=*
# /content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce
# PRINT default FONT PATH
# ********************
# /content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/fonts
# ********************
# Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex.
# Please Notice that Merge the args_dict and json_config ... ...
# Update the config from args input
# Update the config from args input
# {
#   "glyph_ratio": 0.1,
#   "glyph_decay": 0.1,
#   "glyph_warmup": 0,
#   "bert_frozen": "true",
#   "hidden_size": 792,
#   "hidden_dropout_prob": 0.0,
#   "classifier_sign": "single_linear",
#   "clip_grad": 1.0,
#   "bert_config": {
#     "attention_probs_dropout_prob": 0.1,
#     "directionality": "bidi",
#     "hidden_act": "gelu",
#     "hidden_dropout_prob": 0.1,
#     "hidden_size": 768,
#     "initializer_range": 0.02,
#     "intermediate_size": 3072,
#     "max_position_embeddings": 512,
#     "num_attention_heads": 12,
#     "num_hidden_layers": 12,
#     "pooler_fc_size": 768,
#     "pooler_num_attention_heads": 12,
#     "pooler_num_fc_layers": 3,
#     "pooler_size_per_head": 128,
#     "pooler_type": "first_token_transform",
#     "type_vocab_size": 2,
#     "vocab_size": 21128
#   },
#   "graph_config": {
#     "hidden_dropout_prob": 0.5,
#     "max_position_embeddings": 512,
#     "bert_model": "/content/gdrive/MyDrive/Colab Data/Chinese Characters/chinese_L-12_H-768_A-12",
#     "graph_path": "/content/gdrive/MyDrive/Colab Data/Chinese Characters/graphsDictOrder.pickle",
#     "char2word_dim": 0,
#     "char_drop": 0.5,
#     "char_embsize": 0,
#     "gcn_dropout": 0.5,
#     "dropout": 0.5,
#     "num_features": 6,
#     "gcn_hidden": 300,
#     "k": 30,
#     "gcn_layer": "SAGE",
#     "fc_merge": false,
#     "font_channels": 1,
#     "font_name": "cjk/NotoSansCJKsc-Regular.otf",
#     "font_normalize": false,
#     "font_size": 18,
#     "graph_cnn_type": "Yuxian8",
#     "graph_embsize": 24,
#     "graph_groups": 8,
#     "idx2char": null,
#     "idx2word": null,
#     "level": "char",
#     "loss_mask_ids": [
#       0,
#       101,
#       102
#     ],
#     "num_fonts_concat": 1,
#     "output_size": 24,
#     "pretrained_char_embedding": "",
#     "pretrained_word_embedding": "",
#     "random_erase": false,
#     "random_fonts": 0,
#     "subchar_embsize": 512,
#     "subchar_type": "",
#     "use_batch_norm": true,
#     "use_highway": false,
#     "use_layer_norm": false,
#     "use_maxpool": true,
#     "use_traditional": false,
#     "word_embsize": 1024,
#     "yuxian_merge": false,
#     "pool": "sort",
#     "graph_dict": "/content/gdrive/MyDrive/Colab Data/Chinese Characters/unsupGraphModelDict300.bin",
#     "pretrained_graph": "no",
#     "batch_norm": "layer"
#   },
#   "transformer_config": {
#     "max_position_embeddings": 512,
#     "attention_probs_dropout_prob": 0.5,
#     "directionality": "bidi",
#     "hidden_act": "gelu",
#     "hidden_dropout_prob": 0.5,
#     "hidden_size": 792,
#     "initializer_range": 0.02,
#     "intermediate_size": 6144,
#     "num_attention_heads": 24,
#     "num_hidden_layers": 2,
#     "pooler_fc_size": 792,
#     "pooler_num_attention_heads": 12,
#     "pooler_num_fc_layers": 2,
#     "pooler_size_per_head": 256,
#     "pooler_type": "first_token_transform",
#     "type_vocab_size": 2,
#     "vocab_size": 21128
#   },
#   "config_path": "/content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/configs/graph_bert.json",
#   "data_dir": "/content/gdrive/MyDrive/Colab Data/Chinese Characters/sent_cls/fudan",
#   "bert_model": "/content/gdrive/MyDrive/Colab Data/Chinese Characters/chinese_L-12_H-768_A-12",
#   "task_name": "clf",
#   "cuda": true,
#   "max_seq_length": 128,
#   "do_train": true,
#   "do_eval": true,
#   "train_batch_size": 24,
#   "dev_batch_size": 24,
#   "checkpoint": 153,
#   "test_batch_size": 24,
#   "learning_rate": 3e-05,
#   "num_train_epochs": 15.0,
#   "warmup_proportion": 0.0,
#   "local_rank": -1,
#   "gradient_accumulation_steps": 1,
#   "seed": 8008,
#   "nworkers": 1,
#   "step": 1,
#   "export_model": true,
#   "output_name": "/content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/my_export_models/fudan graph/real_1.bin",
#   "data_sign": "fudan",
#   "residual": "no",
#   "training_strat": "bert-glyce-joint",
#   "transformer": "yes"
# }
# read json:
# 100% 3672/3672 [00:00<00:00, 42919.24it/s]
# read json:
# 100% 612/612 [00:00<00:00, 50597.53it/s]
# read json:
# 100% 1837/1837 [00:00<00:00, 49539.24it/s]
# 3672it [00:10, 363.06it/s]
# 612it [00:01, 361.44it/s]
# 1837it [00:05, 359.99it/s]
# !=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!
# Please notice that the bert model if frozen
# the loaded weights of models is
# /content/gdrive/MyDrive/Colab Data/Chinese Characters/chinese_L-12_H-768_A-12
# !-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!
#
# Training Bert...
# ######################################################################
# EPOCH:  0
# 0it [00:00, ?it/s]/content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/utils/optimization.py:142: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:1025.)
#   next_m.mul_(beta1).add_(1 - beta1, grad)
# 151it [01:46,  1.43it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# classification loss
# 0.02938896417617798
# 100% 26/26 [00:16<00:00,  1.59it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.2149 0.9362745098039216 0.9362745098039216 0.9362745098039216 0.9362745098039216
# 100% 77/77 [00:49<00:00,  1.56it/s]
# ............................................................
# TEST: loss, precision, recall, f1, acc
# 0.197 0.9461077844311377 0.9461077844311377 0.9461077844311377 0.9461077844311377
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 153it [02:56,  1.15s/it]
# ######################################################################
# EPOCH:  1
# 151it [01:45,  1.45it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# classification loss
# 0.5429106950759888
# 100% 26/26 [00:16<00:00,  1.56it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.0997 0.9820261437908496 0.9820261437908496 0.9820261437908496 0.9820261437908496
# 100% 77/77 [00:49<00:00,  1.55it/s]
# ............................................................
# TEST: loss, precision, recall, f1, acc
# 0.0809 0.9782253674469243 0.9782253674469243 0.9782253674469243 0.9782253674469243
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 153it [02:55,  1.15s/it]
# ######################################################################
# EPOCH:  2
# 151it [01:45,  1.42it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# classification loss
# 0.002287090988829732
# 100% 26/26 [00:16<00:00,  1.56it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.0515 0.9869281045751634 0.9869281045751634 0.9869281045751634 0.9869281045751634
# 100% 77/77 [00:49<00:00,  1.55it/s]
# ............................................................
# TEST: loss, precision, recall, f1, acc
# 0.0327 0.9885683179096353 0.9885683179096353 0.9885683179096353 0.9885683179096353
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 153it [02:55,  1.15s/it]
# ######################################################################
# EPOCH:  3
# 151it [01:45,  1.44it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# classification loss
# 0.0009689107537269592
# 100% 26/26 [00:16<00:00,  1.57it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.0304 0.9950980392156863 0.9950980392156863 0.9950980392156863 0.9950980392156863
# 100% 77/77 [00:49<00:00,  1.55it/s]
# ............................................................
# TEST: loss, precision, recall, f1, acc
# 0.0215 0.994556341861731 0.994556341861731 0.994556341861731 0.994556341861731
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 153it [02:56,  1.15s/it]
# ######################################################################
# EPOCH:  4
# 151it [01:46,  1.41it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# classification loss
# 0.0022046989761292934
# 100% 26/26 [00:16<00:00,  1.58it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.0381 0.9901960784313726 0.9901960784313726 0.9901960784313726 0.9901960784313726
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 153it [02:04,  1.23it/s]
#
# Training Graph...
# ######################################################################
# EPOCH:  5
# 151it [01:23,  1.68it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# classification loss
# 0.00026436918415129185
# 100% 26/26 [00:16<00:00,  1.58it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.0358 0.9901960784313726 0.9901960784313726 0.9901960784313726 0.9901960784313726
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 153it [01:41,  1.51it/s]
# ######################################################################
# EPOCH:  6
# 151it [01:23,  1.82it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# classification loss
# 0.0035886901896446943
# 100% 26/26 [00:16<00:00,  1.58it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.0358 0.9901960784313726 0.9901960784313726 0.9901960784313726 0.9901960784313726
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 153it [01:41,  1.51it/s]
# ######################################################################
# EPOCH:  7
# 151it [01:23,  1.80it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# classification loss
# 0.00021451567590702325
# 100% 26/26 [00:16<00:00,  1.55it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.0365 0.9901960784313726 0.9901960784313726 0.9901960784313726 0.9901960784313726
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 153it [01:41,  1.51it/s]
# ######################################################################
# EPOCH:  8
# 151it [01:23,  1.82it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# classification loss
# 0.0004992171307094395
# 100% 26/26 [00:16<00:00,  1.54it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.0371 0.9901960784313726 0.9901960784313726 0.9901960784313726 0.9901960784313726
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 153it [01:41,  1.51it/s]
# ######################################################################
# EPOCH:  9
# 151it [01:23,  1.78it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# classification loss
# 0.00017004193796310574
# 100% 26/26 [00:16<00:00,  1.58it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.0374 0.9901960784313726 0.9901960784313726 0.9901960784313726 0.9901960784313726
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 153it [01:41,  1.51it/s]
#
# Training Both...
# ######################################################################
# EPOCH:  10
# 151it [01:56,  1.30it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# classification loss
# 8.175853872671723e-05
# 100% 26/26 [00:16<00:00,  1.55it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.0356 0.9901960784313726 0.9901960784313726 0.9901960784313726 0.9901960784313726
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 153it [02:14,  1.13it/s]
# ######################################################################
# EPOCH:  11
# 151it [01:56,  1.30it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# classification loss
# 7.910447311587632e-05
# 100% 26/26 [00:16<00:00,  1.55it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.0353 0.9918300653594772 0.9918300653594772 0.9918300653594772 0.9918300653594772
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 153it [02:14,  1.13it/s]
# ######################################################################
# EPOCH:  12
# 151it [01:56,  1.28it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# classification loss
# 6.19955753791146e-05
# 100% 26/26 [00:16<00:00,  1.57it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.0358 0.9901960784313726 0.9901960784313726 0.9901960784313726 0.9901960784313726
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 153it [02:14,  1.14it/s]
# ######################################################################
# EPOCH:  13
# 151it [01:56,  1.30it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# classification loss
# 5.666199649567716e-05
# 100% 26/26 [00:16<00:00,  1.58it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.0362 0.9901960784313726 0.9901960784313726 0.9901960784313726 0.9901960784313726
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 153it [02:14,  1.14it/s]
# ######################################################################
# EPOCH:  14
# 151it [01:56,  1.31it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# classification loss
# 4.6202243538573384e-05
# 100% 26/26 [00:16<00:00,  1.55it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.0362 0.9901960784313726 0.9901960784313726 0.9901960784313726 0.9901960784313726
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 153it [02:14,  1.14it/s]
# 100% 77/77 [00:49<00:00,  1.56it/s]
# ............................................................
# TEST: loss, precision, recall, f1, acc
# 0.0217 0.995100707675558 0.995100707675558 0.995100707675558 0.995100707675558
# =&==&==&==&==&==&==&==&==&==&==&==&==&==&==&=
# DEV: current best loss, precision, recall, f1, acc
# 0.0304 0.9950980392156863 0.9950980392156863 0.9950980392156863 0.9950980392156863
# TEST: current best loss, precision, recall, f1, acc
# 0.0217 0.995100707675558 0.995100707675558 0.995100707675558 0.995100707675558
# =&==&==&==&==&==&==&==&==&==&==&==&==&==&==&=

# %%
end = time.perf_counter()
elapsed = end-start
hours = elapsed//(60*60)
mins = (elapsed - hours*60*60)//60
secs = (elapsed - hours*60*60 - mins*60)
print("Time elapsed: %02d:%02d:%02d" % (hours,mins,secs))
# Out:
# Time elapsed: 00:35:37
