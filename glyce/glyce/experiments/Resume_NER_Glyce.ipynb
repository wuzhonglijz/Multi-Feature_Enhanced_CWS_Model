# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !pip install pypinyin pywubi zhconv overrides boto3
# Out:
# Requirement already satisfied: pypinyin in /usr/local/lib/python3.7/dist-packages (0.42.0)
# Requirement already satisfied: pywubi in /usr/local/lib/python3.7/dist-packages (0.0.2)
# Requirement already satisfied: zhconv in /usr/local/lib/python3.7/dist-packages (1.4.2)
# Requirement already satisfied: overrides in /usr/local/lib/python3.7/dist-packages (6.1.0)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.7/dist-packages (1.18.2)
# Requirement already satisfied: typing-utils>=0.0.3 in /usr/local/lib/python3.7/dist-packages (from overrides) (0.1.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from boto3) (0.10.0)
# Requirement already satisfied: botocore<1.22.0,>=1.21.2 in /usr/local/lib/python3.7/dist-packages (from boto3) (1.21.2)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from boto3) (0.5.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.22.0,>=1.21.2->boto3) (2.8.1)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/lib/python3.7/dist-packages (from botocore<1.22.0,>=1.21.2->boto3) (1.26.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.22.0,>=1.21.2->boto3) (1.15.0)

# %%
import time
import torch
print(torch.cuda.get_device_name(0))
start = time.perf_counter()
# Out:
# Tesla V100-SXM2-16GB

# %%
# !python3 "/content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/bin/run_bert_glyce_tagger.py" \
--data_sign resume_ner \
--task_name ner \
--config_path "/content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/configs/ctb6cws_glyce_bert.json" \
--data_dir "/content/gdrive/MyDrive/Colab Data/Chinese Characters/ner/resume" \
--output_name "/content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/my_export_models/resume_ner glyce.bin" \
--bert_model "/content/gdrive/MyDrive/Colab Data/Chinese Characters/chinese_L-12_H-768_A-12" \
--checkpoint 239 \
--seed 8008 \
--max_seq_length 150 \
--do_train \
--do_eval \
--train_batch_size 16 \
--dev_batch_size 16 \
--test_batch_size 16 \
--learning_rate 3e-5 \
--num_train_epochs 15 \
--warmup_proportion 0 \
--training_strat "bert-glyce-joint"
# Out:
# /content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce
# PATH to render.py
# =*=*=*=*=*=*=*=*=*=*
# /content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce
# PRINT default FONT PATH
# ********************
# /content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/fonts
# ********************
# /usr/local/lib/python3.7/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.6) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex.
# Please Notice that Merge the args_dict and json_config ... ...
# {
#   "glyph_ratio": 1e-06,
#   "glyph_decay": 0.85,
#   "glyph_warmup": 0,
#   "bert_frozen": "true",
#   "hidden_size": 1536,
#   "hidden_dropout_prob": 0,
#   "clip_grad": 1,
#   "bert_config": {
#     "attention_probs_dropout_prob": 0.1,
#     "directionality": "bidi",
#     "hidden_act": "gelu",
#     "hidden_dropout_prob": 0.1,
#     "hidden_size": 768,
#     "initializer_range": 0.02,
#     "intermediate_size": 3072,
#     "max_position_embeddings": 512,
#     "num_attention_heads": 12,
#     "num_hidden_layers": 12,
#     "pooler_fc_size": 768,
#     "pooler_num_attention_heads": 12,
#     "pooler_num_fc_layers": 3,
#     "pooler_size_per_head": 128,
#     "pooler_type": "first_token_transform",
#     "type_vocab_size": 2,
#     "vocab_size": 21128
#   },
#   "glyph_config": {
#     "hidden_dropout_prob": 0.5,
#     "max_position_embeddings": 512,
#     "bert_model": "/content/gdrive/MyDrive/Colab Data/Chinese Characters/chinese_L-12_H-768_A-12",
#     "char2word_dim": 0,
#     "char_drop": 0.3,
#     "char_embsize": 0,
#     "cnn_dropout": 0.5,
#     "dropout": 0.5,
#     "fc_merge": false,
#     "font_channels": 1,
#     "font_name": "cjk/NotoSansCJKsc-Regular.otf",
#     "font_normalize": false,
#     "font_size": 18,
#     "glyph_cnn_type": "Yuxian8",
#     "glyph_embsize": 384,
#     "glyph_groups": 8,
#     "idx2char": null,
#     "idx2word": null,
#     "level": "char",
#     "loss_mask_ids": [
#       0,
#       102,
#       101
#     ],
#     "num_fonts_concat": 2,
#     "output_size": 768,
#     "pretrained_char_embedding": "",
#     "pretrained_word_embedding": "",
#     "random_erase": false,
#     "random_fonts": 0,
#     "subchar_embsize": 512,
#     "subchar_type": "",
#     "use_batch_norm": true,
#     "use_highway": false,
#     "use_layer_norm": false,
#     "use_maxpool": true,
#     "use_traditional": false,
#     "word_embsize": 1024,
#     "yuxian_merge": false,
#     "font_names": []
#   },
#   "transformer_config": {
#     "max_position_embeddings": 512,
#     "attention_probs_dropout_prob": 0.1,
#     "directionality": "bidi",
#     "hidden_act": "gelu",
#     "hidden_dropout_prob": 0.5,
#     "hidden_size": 1536,
#     "initializer_range": 0.02,
#     "intermediate_size": 6144,
#     "num_attention_heads": 24,
#     "num_hidden_layers": 1,
#     "pooler_fc_size": 1536,
#     "pooler_num_attention_heads": 12,
#     "pooler_num_fc_layers": 12,
#     "pooler_size_per_head": 256,
#     "pooler_type": "first_token_transform",
#     "type_vocab_size": 2,
#     "vocab_size": 21128
#   },
#   "config_path": "/content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/configs/ctb6cws_glyce_bert.json",
#   "data_dir": "/content/gdrive/MyDrive/Colab Data/Chinese Characters/ner/resume",
#   "bert_model": "/content/gdrive/MyDrive/Colab Data/Chinese Characters/chinese_L-12_H-768_A-12",
#   "task_name": "ner",
#   "cuda": true,
#   "max_seq_length": 150,
#   "do_train": true,
#   "do_eval": true,
#   "train_batch_size": 16,
#   "dev_batch_size": 16,
#   "checkpoint": 239,
#   "test_batch_size": 16,
#   "learning_rate": 3e-05,
#   "num_train_epochs": 15.0,
#   "warmup_proportion": 0.0,
#   "local_rank": -1,
#   "gradient_accumulation_steps": 1,
#   "seed": 8008,
#   "export_model": true,
#   "output_name": "/content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/my_export_models/resume_ner glyce/training_2.bin",
#   "data_sign": "resume_ner",
#   "classifier_sign": "multi_nonlinear",
#   "residual": "no",
#   "training_strat": "bert-glyce-joint"
# }
# 3821it [00:01, 3506.22it/s]
# 463it [00:00, 3801.63it/s]
# 477it [00:00, 3827.21it/s]
# !=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!!=!
# Please notice that the bert model if frozen
# the loaded weights of models is
# /content/gdrive/MyDrive/Colab Data/Chinese Characters/chinese_L-12_H-768_A-12
# !-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!!-!
# ######################################################################
# EPOCH:  0
# 0it [00:00, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
#   warnings.warn(warning.format(ret))
# /content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/utils/optimization.py:142: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:1025.)
#   next_m.mul_(beta1).add_(1 - beta1, grad)
# 238it [01:17,  3.07it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# taggging loss, glyph loss
# 0.05387328937649727 29.49768829345703
# 100% 29/29 [00:06<00:00,  4.54it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.0255 0.9097 0.9285 0.919 0.9748
# 100% 30/30 [00:06<00:00,  4.60it/s]
# ............................................................
# TEST: loss, precision, recall, f1, acc
# 0.0304 0.9125 0.9287 0.9205 0.9737
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 239it [01:32,  2.57it/s]
# ######################################################################
# EPOCH:  1
# 238it [01:17,  3.11it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# taggging loss, glyph loss
# 0.006942691281437874 20.237804412841797
# 100% 29/29 [00:06<00:00,  4.59it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.02 0.9444 0.9532 0.9488 0.9784
# 100% 30/30 [00:06<00:00,  4.60it/s]
# ............................................................
# TEST: loss, precision, recall, f1, acc
# 0.0242 0.9479 0.9502 0.9491 0.98
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 239it [01:32,  2.58it/s]
# ######################################################################
# EPOCH:  2
# 238it [01:17,  3.07it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# taggging loss, glyph loss
# 0.022922037169337273 20.0316219329834
# 100% 29/29 [00:06<00:00,  4.58it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.0175 0.9349 0.9492 0.942 0.9799
# 100% 30/30 [00:06<00:00,  4.60it/s]
# ............................................................
# TEST: loss, precision, recall, f1, acc
# 0.0229 0.9515 0.9515 0.9515 0.9798
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 239it [01:32,  2.57it/s]
# ######################################################################
# EPOCH:  3
# 238it [01:17,  3.09it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# taggging loss, glyph loss
# 0.0007903650403022766 20.609088897705078
# 100% 29/29 [00:06<00:00,  4.58it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.0197 0.9431 0.9526 0.9478 0.9797
# 100% 30/30 [00:06<00:00,  4.60it/s]
# ............................................................
# TEST: loss, precision, recall, f1, acc
# 0.0285 0.9531 0.9478 0.9504 0.9777
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 239it [01:30,  2.64it/s]
# ######################################################################
# EPOCH:  4
# 238it [01:16,  3.11it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# taggging loss, glyph loss
# 0.000508022727444768 19.619596481323242
# 100% 29/29 [00:06<00:00,  4.58it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.0233 0.9338 0.9419 0.9378 0.9804
# 100% 30/30 [00:06<00:00,  4.60it/s]
# ............................................................
# TEST: loss, precision, recall, f1, acc
# 0.034 0.9562 0.9521 0.9541 0.9781
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 239it [01:32,  2.59it/s]
# ######################################################################
# EPOCH:  5
# 238it [01:12,  3.30it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# taggging loss, glyph loss
# 0.00025025440845638514 23.253997802734375
# 100% 29/29 [00:06<00:00,  4.59it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.0234 0.9448 0.9486 0.9467 0.9806
# 100% 30/30 [00:06<00:00,  4.60it/s]
# ............................................................
# TEST: loss, precision, recall, f1, acc
# 0.0334 0.9563 0.9545 0.9554 0.979
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 239it [01:28,  2.71it/s]
# ######################################################################
# EPOCH:  6
# 238it [01:12,  3.26it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# taggging loss, glyph loss
# 0.0007146561401896179 24.392398834228516
# 100% 29/29 [00:06<00:00,  4.58it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.024 0.9384 0.9466 0.9425 0.9804
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 239it [01:19,  3.01it/s]
# ######################################################################
# EPOCH:  7
# 238it [01:12,  3.33it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# taggging loss, glyph loss
# 0.00021407617896329612 24.472562789916992
# 100% 29/29 [00:06<00:00,  4.58it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.0239 0.9436 0.9499 0.9467 0.9807
# 100% 30/30 [00:06<00:00,  4.60it/s]
# ............................................................
# TEST: loss, precision, recall, f1, acc
# 0.0353 0.9568 0.9515 0.9541 0.9787
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 239it [01:25,  2.79it/s]
# ######################################################################
# EPOCH:  8
# 238it [01:12,  3.25it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# taggging loss, glyph loss
# 9.888719796435907e-05 24.419902801513672
# 100% 29/29 [00:06<00:00,  4.59it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.0246 0.9442 0.9499 0.9471 0.9807
# 100% 30/30 [00:06<00:00,  4.61it/s]
# ............................................................
# TEST: loss, precision, recall, f1, acc
# 0.0349 0.9563 0.9533 0.9548 0.9791
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 239it [01:27,  2.72it/s]
# ######################################################################
# EPOCH:  9
# 238it [01:12,  3.30it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# taggging loss, glyph loss
# 0.0002478939713910222 24.776573181152344
# 100% 29/29 [00:06<00:00,  4.58it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.0247 0.9417 0.9492 0.9454 0.9807
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 239it [01:19,  3.01it/s]
# ######################################################################
# EPOCH:  10
# 238it [01:35,  2.52it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# taggging loss, glyph loss
# 0.00017293189011979848 24.79541015625
# 100% 29/29 [00:06<00:00,  4.59it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.0244 0.9453 0.9466 0.9459 0.9792
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 239it [01:41,  2.34it/s]
# ######################################################################
# EPOCH:  11
# 238it [02:07,  1.86it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# taggging loss, glyph loss
# 0.0006065019406378269 24.86269760131836
# 100% 29/29 [00:06<00:00,  4.59it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.0261 0.9489 0.9552 0.9521 0.9816
# 100% 30/30 [00:06<00:00,  4.61it/s]
# ............................................................
# TEST: loss, precision, recall, f1, acc
# 0.0406 0.9575 0.9539 0.9557 0.9775
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 239it [02:23,  1.67it/s]
# ######################################################################
# EPOCH:  12
# 238it [02:08,  1.85it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# taggging loss, glyph loss
# 7.563654071418568e-05 23.789016723632812
# 100% 29/29 [00:06<00:00,  4.59it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.0272 0.9457 0.9532 0.9494 0.9812
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 239it [02:14,  1.77it/s]
# ######################################################################
# EPOCH:  13
# 238it [02:07,  1.86it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# taggging loss, glyph loss
# 5.731529381591827e-05 24.198156356811523
# 100% 29/29 [00:06<00:00,  4.58it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.0274 0.9463 0.9532 0.9498 0.9813
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 239it [02:14,  1.78it/s]
# ######################################################################
# EPOCH:  14
# 238it [02:07,  1.87it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# taggging loss, glyph loss
# 5.178165520192124e-05 25.31147003173828
# 100% 29/29 [00:06<00:00,  4.59it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.0274 0.9469 0.9532 0.9501 0.9814
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 239it [02:14,  1.78it/s]
# 100% 30/30 [00:06<00:00,  4.61it/s]
# ............................................................
# TEST: loss, precision, recall, f1, acc
# 0.042 0.9581 0.9545 0.9563 0.9778
# =&==&==&==&==&==&==&==&==&==&==&==&==&==&==&=
# DEV: current best loss, precision, recall, f1, acc
# 0.0261 0.9489 0.9552 0.9521 0.9816
# TEST: current best loss, precision, recall, f1, acc
# 0.042 0.9581 0.9545 0.9563 0.9778
# =&==&==&==&==&==&==&==&==&==&==&==&==&==&==&=

# %%
end = time.perf_counter()
elapsed = end-start
hours = elapsed//(60*60)
mins = (elapsed - hours*60*60)//60
secs = (elapsed - hours*60*60 - mins*60)
print("Time elapsed: %02d:%02d:%02d" % (hours,mins,secs))
# Out:
# Time elapsed: 00:26:03
