# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !pip install pypinyin pywubi zhconv overrides boto3
# Out:
# Requirement already satisfied: pypinyin in /usr/local/lib/python3.7/dist-packages (0.42.0)
# Requirement already satisfied: pywubi in /usr/local/lib/python3.7/dist-packages (0.0.2)
# Requirement already satisfied: zhconv in /usr/local/lib/python3.7/dist-packages (1.4.1)
# Requirement already satisfied: overrides in /usr/local/lib/python3.7/dist-packages (6.1.0)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.7/dist-packages (1.17.103)
# Requirement already satisfied: typing-utils>=0.0.3 in /usr/local/lib/python3.7/dist-packages (from overrides) (0.1.0)
# Requirement already satisfied: s3transfer<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from boto3) (0.4.2)
# Requirement already satisfied: botocore<1.21.0,>=1.20.103 in /usr/local/lib/python3.7/dist-packages (from boto3) (1.20.103)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from boto3) (0.10.0)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/lib/python3.7/dist-packages (from botocore<1.21.0,>=1.20.103->boto3) (1.26.6)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.21.0,>=1.20.103->boto3) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.21.0,>=1.20.103->boto3) (1.15.0)

# %%
import time
import torch
print(torch.cuda.get_device_name(0))
start = time.perf_counter()
# Out:
# Tesla V100-SXM2-16GB

# %%
# !python3 "/content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/bin/run_bert_classifier.py" \
--data_sign bq \
--task_name clf \
--data_dir "/content/gdrive/MyDrive/Colab Data/Chinese Characters/sent_pair/bq" \
--output_name "/content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/my_export_models/bq bert.bin" \
--config_path "/content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/configs/bert.json" \
--bert_model "/content/gdrive/MyDrive/Colab Data/Chinese Characters/chinese_L-12_H-768_A-12" \
--max_seq_length 64 \
--do_train \
--do_eval \
--seed 3306 \
--train_batch_size 32 \
--dev_batch_size 32 \
--test_batch_size 32 \
--learning_rate 2e-5 \
--num_train_epochs 5 \
--warmup_proportion 0.1 \
--checkpoint 3125
# Out:
# check the root_path of this repo
# /content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce
# /content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce
# PATH to render.py
# =*=*=*=*=*=*=*=*=*=*
# /content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce
# PRINT default FONT PATH
# ********************
# /content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/fonts
# ********************
# /usr/local/lib/python3.7/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.6) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex.
# Please Notice that Merge the args_dict and json_config ... ...
# Update the config from args input
# {
#   "bert_frozen": "false",
#   "hidden_size": 768,
#   "hidden_dropout_prob": 0.1,
#   "classifier_sign": "single_linear",
#   "clip_grad": 1.0,
#   "bert_config": {
#     "attention_probs_dropout_prob": 0.1,
#     "directionality": "bidi",
#     "hidden_act": "gelu",
#     "hidden_dropout_prob": 0.1,
#     "hidden_size": 768,
#     "initializer_range": 0.02,
#     "intermediate_size": 3072,
#     "max_position_embeddings": 512,
#     "num_attention_heads": 12,
#     "num_hidden_layers": 12,
#     "pooler_fc_size": 768,
#     "pooler_num_attention_heads": 12,
#     "pooler_num_fc_layers": 3,
#     "pooler_size_per_head": 128,
#     "pooler_type": "first_token_transform",
#     "type_vocab_size": 2,
#     "vocab_size": 21128
#   },
#   "config_path": "/content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/configs/bert.json",
#   "data_dir": "/content/gdrive/MyDrive/Colab Data/Chinese Characters/sent_pair/bq",
#   "bert_model": "/content/gdrive/MyDrive/Colab Data/Chinese Characters/chinese_L-12_H-768_A-12",
#   "task_name": "clf",
#   "cuda": true,
#   "max_seq_length": 64,
#   "do_train": true,
#   "do_eval": true,
#   "train_batch_size": 32,
#   "dev_batch_size": 32,
#   "checkpoint": 3125,
#   "test_batch_size": 32,
#   "learning_rate": 2e-05,
#   "num_train_epochs": 5.0,
#   "warmup_proportion": 0.1,
#   "local_rank": -1,
#   "gradient_accumulation_steps": 1,
#   "seed": 3306,
#   "nworkers": 1,
#   "export_model": true,
#   "output_name": "/content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/my_export_models/bq bert/try2.bin",
#   "data_sign": "bq"
# }
# 99999it [00:16, 5943.52it/s]
# 9999it [00:01, 6172.11it/s]
# 9999it [00:01, 5998.62it/s]
# ######################################################################
# EPOCH:  0
# 0it [00:00, ?it/s]/content/gdrive/MyDrive/Colab Data/Chinese Characters/glyce/glyce/utils/optimization.py:142: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:1025.)
#   next_m.mul_(beta1).add_(1 - beta1, grad)
# 3123it [10:40,  4.88it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# classification loss
# 0.2502048909664154
# 100% 313/313 [00:26<00:00, 11.96it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.3483 0.8564856485648565 0.8564856485648565 0.8564856485648565 0.8564856485648565
# 100% 313/313 [00:26<00:00, 11.95it/s]
# ............................................................
# TEST: loss, precision, recall, f1, acc
# 0.3819 0.8421842184218422 0.8421842184218422 0.8421842184218422 0.8421842184218422
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 3125it [11:35,  4.49it/s]
# ######################################################################
# EPOCH:  1
# 3123it [10:35,  4.94it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# classification loss
# 0.05853698402643204
# 100% 313/313 [00:25<00:00, 12.04it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.4113 0.845084508450845 0.845084508450845 0.8450845084508452 0.845084508450845
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 3125it [11:01,  4.72it/s]
# ######################################################################
# EPOCH:  2
# 3123it [10:28,  5.02it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# classification loss
# 0.07871236652135849
# 100% 313/313 [00:25<00:00, 12.07it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.5555 0.8509850985098509 0.8509850985098509 0.8509850985098509 0.8509850985098509
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 3125it [10:54,  4.77it/s]
# ######################################################################
# EPOCH:  3
# 3123it [10:29,  4.94it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# classification loss
# 0.0007499792263843119
# 100% 313/313 [00:26<00:00, 12.03it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.7466 0.8551855185518552 0.8551855185518552 0.8551855185518552 0.8551855185518552
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 3125it [10:56,  4.76it/s]
# ######################################################################
# EPOCH:  4
# 3123it [10:31,  4.93it/s]-*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# current training loss is :
# classification loss
# 7.063214434310794e-05
# 100% 313/313 [00:26<00:00, 12.02it/s]
# ............................................................
# DEV: loss, precision, recall, f1, acc
# 0.906 0.8520852085208521 0.8520852085208521 0.8520852085208521 0.8520852085208521
# -*--*--*--*--*--*--*--*--*--*--*--*--*--*--*-
# 3125it [10:57,  4.75it/s]
# =&==&==&==&==&==&==&==&==&==&==&==&==&==&==&=
# DEV: current best loss, precision, recall, f1, acc
# 0.3483 0.8564856485648565 0.8564856485648565 0.8564856485648565 0.8564856485648565
# TEST: current best loss, precision, recall, f1, acc
# 0.3819 0.8421842184218422 0.8421842184218422 0.8421842184218422 0.8421842184218422
# =&==&==&==&==&==&==&==&==&==&==&==&==&==&==&=

# %%
end = time.perf_counter()
elapsed = end-start
hours = elapsed//(60*60)
mins = (elapsed - hours*60*60)//60
secs = (elapsed - hours*60*60 - mins*60)
print("Time elapsed: %02d:%02d:%02d" % (hours,mins,secs))
# Out:
# Time elapsed: 00:56:21
