# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !pip install pypinyin pywubi zhconv overrides boto3 tqdm
# Out:
# ...
#   Using cached tqdm-4.64.0-py2.py3-none-any.whl (78 kB)
# ...

# %%
import time
import torch
print(torch.cuda.get_device_name(0))
start = time.perf_counter()
# Out:
# NVIDIA GeForce RTX 2070

# %%
# !python3 "../bin/run_bert_tagger.py" \
--data_sign resume_ner \
--config_path "../configs/bert.json" \
--data_dir "/home/wzl/msc/StrokeOrderEmbeddings/data/ner/resume" \
--bert_model "/home/wzl/msc/StrokeOrderEmbeddings/data/chinese_L-12_H-768_A-12" \
--output_name "/home/wzl/msc/StrokeOrderEmbeddings/my_models/bert.bin" \
--task_name ner \
--max_seq_length 90 \
--do_train \
--seed 9165 \
--do_eval \
--train_batch_size 32 \
--dev_batch_size 32 \
--test_batch_size 32 \
--learning_rate 3e-5 \
--num_train_epochs 1 \
--checkpoint 100
# Out:
# Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex.
# Please Notice that Merge the args_dict and json_config ... ...
# Update the config from args input
# {
#   "bert_frozen": "false",
#   "hidden_size": 768,
#   "hidden_dropout_prob": 0.1,
#   "classifier_sign": "multi_nonlinear",
#   "clip_grad": 1.0,
#   "bert_config": {
#     "attention_probs_dropout_prob": 0.1,
#     "directionality": "bidi",
#     "hidden_act": "gelu",
#     "hidden_dropout_prob": 0.1,
#     "hidden_size": 768,
#     "initializer_range": 0.02,
#     "intermediate_size": 3072,
#     "max_position_embeddings": 512,
#     "num_attention_heads": 12,
#     "num_hidden_layers": 12,
#     "pooler_fc_size": 768,
#     "pooler_num_attention_heads": 12,
#     "pooler_num_fc_layers": 3,
#     "pooler_size_per_head": 128,
#     "pooler_type": "first_token_transform",
#     "type_vocab_size": 2,
#     "vocab_size": 21128
#   },
#   "config_path": "../configs/bert.json",
# ...

# %%
end = time.perf_counter()
elapsed = end-start
hours = elapsed//(60*60)
mins = (elapsed - hours*60*60)//60
secs = (elapsed - hours*60*60 - mins*60)
print("Time elapsed: %02d:%02d:%02d" % (hours,mins,secs))
# Out:
# Time elapsed: 00:04:31
